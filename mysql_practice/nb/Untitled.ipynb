# %%
from sqlalchemy import create_engine, text
engine = create_engine("mysql+mysqlconnector://root:abc@127.0.0.1:3306/cs544")
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File /usr/local/lib/python3.9/dist-packages/mysql/connector/connection_cext.py:302, in CMySQLConnection._open_connection(self)
#     301 try:
# --> 302     self._cmysql.connect(**cnx_kwargs)
#     303     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on '127.0.0.1:3306' (111)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/base.py:3292, in Engine.raw_connection(self)
#    3271 """Return a "raw" DBAPI connection from the connection pool.
#    3272
#    3273 The returned object is a proxied version of the DBAPI
#    (...)
#    3290
#    3291 """
# -> 3292 return self.pool.connect()
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
#     447 The connection is instrumented such that when its
#    (...)
#     450
#     451 """
# --> 452 return _ConnectionFairy._checkout(self)
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py:1269, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1268 if not fairy:
# -> 1269     fairy = _ConnectionRecord.checkout(pool)
#    1271     if threadconns is not None:
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/impl.py:170, in QueuePool._do_get(self)
#     169 with util.safe_reraise():
# --> 170     self._dec_overflow()
#     171 raise
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/impl.py:167, in QueuePool._do_get(self)
#     166 try:
# --> 167     return self._create_connection()
#     168 except:
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py:393, in Pool._create_connection(self)
#     391 """Called by subclasses to create a new ConnectionRecord."""
# --> 393 return _ConnectionRecord(self)
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py:903, in _ConnectionRecord.__connect(self)
#     902     with util.safe_reraise():
# --> 903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py:898, in _ConnectionRecord.__connect(self)
#     897 self.starttime = time.time()
# --> 898 self.dbapi_connection = connection = pool._invoke_creator(self)
#     899 pool.logger.debug("Created new connection %r", connection)
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/create.py:637, in create_engine.<locals>.connect(connection_record)
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.9/dist-packages/mysql/connector/pooling.py:293, in connect(*args, **kwargs)
#     292 if CMySQLConnection and not use_pure:
# --> 293     return CMySQLConnection(*args, **kwargs)
#     294 return MySQLConnection(*args, **kwargs)
#
# File /usr/local/lib/python3.9/dist-packages/mysql/connector/connection_cext.py:128, in CMySQLConnection.__init__(self, **kwargs)
#     127 try:
# --> 128     self.connect(**kwargs)
#     129 except Exception:
#
# File /usr/local/lib/python3.9/dist-packages/mysql/connector/abstracts.py:1217, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1216 self.disconnect()
# -> 1217 self._open_connection()
#    1218 # Server does not allow to run any other statement different from ALTER
#    1219 # when user's password has been expired.
#
# File /usr/local/lib/python3.9/dist-packages/mysql/connector/connection_cext.py:307, in CMySQLConnection._open_connection(self)
#     306 except MySQLInterfaceError as err:
# --> 307     raise get_mysql_exception(
#     308         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     309     ) from err
#     311 self._do_handshake()
#
# DatabaseError: 2003 (HY000): Can't connect to MySQL server on '127.0.0.1:3306' (111)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[1], line 3
#       1 from sqlalchemy import create_engine, text
#       2 engine = create_engine("mysql+mysqlconnector://root:abc@127.0.0.1:3306/cs544")
# ----> 3 conn = engine.connect()
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/base.py:3268, in Engine.connect(self)
#    3245 def connect(self) -> Connection:
#    3246     """Return a new :class:`_engine.Connection` object.
#    3247
#    3248     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3265
#    3266     """
# -> 3268     return self._connection_cls(self)
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/base.py:2430, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2428 elif should_wrap:
#    2429     assert sqlalchemy_exception is not None
# -> 2430     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2431 else:
#    2432     assert exc_info[1] is not None
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/base.py:3292, in Engine.raw_connection(self)
#    3270 def raw_connection(self) -> PoolProxiedConnection:
#    3271     """Return a "raw" DBAPI connection from the connection pool.
#    3272
#    3273     The returned object is a proxied version of the DBAPI
#    (...)
#    3290
#    3291     """
# -> 3292     return self.pool.connect()
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
#     444 def connect(self) -> PoolProxiedConnection:
#     445     """Return a DBAPI connection from the pool.
#     446
#     447     The connection is instrumented such that when its
#    (...)
#     450
#     451     """
# --> 452     return _ConnectionFairy._checkout(self)
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py:1269, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1261 @classmethod
#    1262 def _checkout(
#    1263     cls,
#    (...)
#    1266     fairy: Optional[_ConnectionFairy] = None,
#    1267 ) -> _ConnectionFairy:
#    1268     if not fairy:
# -> 1269         fairy = _ConnectionRecord.checkout(pool)
#    1271         if threadconns is not None:
#    1272             threadconns.current = weakref.ref(fairy)
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     714     rec = cast(_ConnectionRecord, pool._do_get())
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#     719     dbapi_connection = rec.get_connection()
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/impl.py:170, in QueuePool._do_get(self)
#     168     except:
#     169         with util.safe_reraise():
# --> 170             self._dec_overflow()
#     171         raise
#     172 else:
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/impl.py:167, in QueuePool._do_get(self)
#     165 if self._inc_overflow():
#     166     try:
# --> 167         return self._create_connection()
#     168     except:
#     169         with util.safe_reraise():
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py:393, in Pool._create_connection(self)
#     390 def _create_connection(self) -> ConnectionPoolEntry:
#     391     """Called by subclasses to create a new ConnectionRecord."""
# --> 393     return _ConnectionRecord(self)
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     676 self.__pool = pool
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py:903, in _ConnectionRecord.__connect(self)
#     901 except BaseException as e:
#     902     with util.safe_reraise():
# --> 903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#     907     if pool.dispatch.first_connect:
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py:898, in _ConnectionRecord.__connect(self)
#     896 try:
#     897     self.starttime = time.time()
# --> 898     self.dbapi_connection = connection = pool._invoke_creator(self)
#     899     pool.logger.debug("Created new connection %r", connection)
#     900     self.fresh = True
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/create.py:637, in create_engine.<locals>.connect(connection_record)
#     634         if connection is not None:
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.9/dist-packages/mysql/connector/pooling.py:293, in connect(*args, **kwargs)
#     290         raise ImportError(ERROR_NO_CEXT)
#     292 if CMySQLConnection and not use_pure:
# --> 293     return CMySQLConnection(*args, **kwargs)
#     294 return MySQLConnection(*args, **kwargs)
#
# File /usr/local/lib/python3.9/dist-packages/mysql/connector/connection_cext.py:128, in CMySQLConnection.__init__(self, **kwargs)
#     126 if kwargs:
#     127     try:
# --> 128         self.connect(**kwargs)
#     129     except Exception:
#     130         self.close()
#
# File /usr/local/lib/python3.9/dist-packages/mysql/connector/abstracts.py:1217, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1214     self.config(**kwargs)
#    1216 self.disconnect()
# -> 1217 self._open_connection()
#    1218 # Server does not allow to run any other statement different from ALTER
#    1219 # when user's password has been expired.
#    1220 if not self._client_flags & ClientFlag.CAN_HANDLE_EXPIRED_PASSWORDS:
#
# File /usr/local/lib/python3.9/dist-packages/mysql/connector/connection_cext.py:307, in CMySQLConnection._open_connection(self)
#     305         self.converter.str_fallback = self._converter_str_fallback
#     306 except MySQLInterfaceError as err:
# --> 307     raise get_mysql_exception(
#     308         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     309     ) from err
#     311 self._do_handshake()
#
# DatabaseError: (mysql.connector.errors.DatabaseError) 2003 (HY000): Can't connect to MySQL server on '127.0.0.1:3306' (111)
# (Background on this error at: https://sqlalche.me/e/20/4xp6)

# %%
# !ps aux
# Out:
# /bin/sh: 1: ps: not found

# %%
# !ls
# Out:
# Untitled.ipynb
